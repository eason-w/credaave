# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
from ipywidgets import widgets

# %% [markdown]
# # CredAAVE

# %% [markdown]
# A tool allowing you to check the credit score of accounts using AAVE.
# (Insert why this is a problem, explain credit score)
# Built using GraphQL, AAVE, and PyTorch
#
# [Video Demo](https://loom.com/)
# [GitHub](https://github.com/)
#
# -------

# %%
path = Path()
learn_inf = load_learner(path/'testing2.pkl', cpu=True)
txt_input = widgets.Text()
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
pred_data = {"avg_borrowRate" : [1], "avg_amount_borrowed" : [2], "num_borrows" : [3], "num_prev_defaults" : [4]}
pred_df = pd.DataFrame(pred_data)
pred_df_true = pred_df.isnull().sum()/len(pred_df)

# %%
float(learn_inf.predict(pred_df_true)[2])
# Out:
# -0.003436340019106865

# %%
#Error is likely here
def on_text_change(change):
    lbl_pred.value = ''
    txt = txt_input
    out_pl.clear_output()
    lbl_pred.value = float(learn_inf.predict(txt)[2])

##def on_data_change(change):
##    lbl_pred.value = ''
##    img = PILImage.create(btn_upload.data[-1])
##    out_pl.clear_output()
##    with out_pl: display(img.to_thumb(128,128))
##    pred,pred_idx,probs = learn_inf.predict(img)
##    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# %%
output_text = widgets.Text()
input_text = widgets.Text()

def bind_input_to_output(sender):
    output_text.value = input_text.value
    
input_text.on_submit(bind_input_to_output)

input_text
# Out:
# Text(value='')

# %%
output_text

# output_text = float(learn_inf.predict(output_text)[2])
# Out:
# Text(value='4331')

# %%
txt_input.observe(on_text_change, names=['data'])

#txt_input = widgets.Text()
#txt_input.observe(on_text_change)

# %%
#display(VBox([widgets.Label('Input a valid Ethereum address:'), txt_input, out_pl, lbl_pred]))

display(VBox([widgets.Label('Input a valid Ethereum address:'), txt_input, out_pl, lbl_pred]))
# Out:
# VBox(children=(Label(value='Input a valid Ethereum address:'), Text(value=''), Output(), Label(value='')))
